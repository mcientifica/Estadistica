# %% [markdown]
# ## EJERCICIO CORRELACIÓN

# %% [markdown]
# ![image.png](attachment:65b2d67d-23cb-4e85-a836-407dff21bcac.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
asignaturas = pd.read_excel("Correlación.xlsx", sheet_name="Asignaturas")
monedas = pd.read_excel("Correlación.xlsx", sheet_name="Monedas")
alturas = pd.read_excel("Correlación.xlsx", sheet_name="Lectura vs Altura")
consumos = pd.read_excel("Correlación.xlsx", sheet_name="ConsumoTV")

# %% [markdown]
# ### Horas de Estudio vs Nota Obtenida

# %%
# Mostrar primeros resultados
asignaturas.head()
# Out:
#    HorasEstudio  NotaObtenida
# 0           9.2             6
# 1          18.1            10
# 2           8.4             5
# 3          12.1             4
# 4          17.9             9

# %%
# Calcular correlación
np.corrcoef(x=asignaturas["HorasEstudio"], y=asignaturas["NotaObtenida"])
# Out:
# array([[1.       , 0.9187477],
#        [0.9187477, 1.       ]])

# %%
# Graficar
sns.regplot(data=asignaturas, x="HorasEstudio", y="NotaObtenida", color='blue')
sns.scatterplot(data=asignaturas, x="HorasEstudio", y="NotaObtenida", color='red')
plt.show()

# %% [markdown]
# ### GastoDolares vs GastoEuros

# %%
# Mostrar primeros resultados
monedas.head()
# Out:
#    GastoDolares  GastoEuros
# 0           933      858.36
# 1           770      708.40
# 2           635      584.20
# 3           594      546.48
# 4           888      816.96

# %%
# Calcular correlación
np.corrcoef(x=monedas["GastoDolares"], y=monedas["GastoEuros"])
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
# Graficar
sns.regplot(data=monedas, x="GastoDolares", y="GastoEuros", color="blue")
sns.scatterplot(data=monedas, x="GastoDolares", y="GastoEuros", color="red")
plt.show()

# %% [markdown]
# ### Altura vs Libros

# %%
# Mostrar primeros resultados
alturas.head()
# Out:
#    LibrosLeidos  AlturaPersona
# 0            35           1.75
# 1            35           1.93
# 2             5           1.83
# 3            19           1.74
# 4            33           2.17

# %%
# Calcular correlación
np.corrcoef(x=alturas["LibrosLeidos"], y=alturas["AlturaPersona"])
# Out:
# array([[1.        , 0.01167662],
#        [0.01167662, 1.        ]])

# %%
# Graficar
sns.regplot(data=alturas, x="LibrosLeidos", y="AlturaPersona", color="blue")
sns.scatterplot(data=alturas, x="LibrosLeidos", y="AlturaPersona", color="red")
plt.show()

# %% [markdown]
# ### Fuera de casa vs ConsumoTV

# %%
# Mostrar primeros resultados
consumos.head()
# Out:
#    HorasFueraHogar  ConsumoTV
# 0         6.987316  10.593379
# 1         2.808274  14.902238
# 2        11.021217   4.776801
# 3         7.831369   6.712287
# 4         7.630385   7.283262

# %%
# Calcular correlación
np.corrcoef(x=consumos["HorasFueraHogar"], y=consumos["ConsumoTV"])
# Out:
# array([[ 1.        , -0.80606795],
#        [-0.80606795,  1.        ]])

# %%
# Graficar
sns.regplot(data=consumos, x="HorasFueraHogar", y="ConsumoTV", color="blue")
sns.scatterplot(data=consumos, x="HorasFueraHogar", y="ConsumoTV", color="red")
plt.show()
